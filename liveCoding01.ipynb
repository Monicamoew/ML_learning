# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load Pandas dataframe
dataset = pd.read_csv('/home/stephen/bittiger/week01/data/train.csv')
dataset_test = pd.read_csv('/home/stephen/bittiger/week01/data/test.csv')

# %%
dataset.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9   ...        cont6  \
# 0   1    A    B    A    B    A    A    A    A    B   ...     0.718367
# 1   2    A    B    A    A    A    A    A    A    B   ...     0.438917
# 2   5    A    B    A    A    B    A    A    A    B   ...     0.289648
# 3  10    B    B    A    B    A    A    A    A    B   ...     0.440945
# 4  11    A    B    A    B    A    A    A    A    B   ...     0.178193
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0  0.335060  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493
# 1  0.436585  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431
# 2  0.315545  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709
# 3  0.391128  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077
# 4  0.247408  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011
#
#      cont14     loss
# 0  0.714843  2213.18
# 1  0.304496  1283.60
# 2  0.774425  3005.09
# 3  0.602642   939.85
# 4  0.432606  2763.85
#
# [5 rows x 132 columns]

# %% [raw]
# # Categorical Features (Lower, Higher )
# # Continouse Numeric Features
# # Time / Date
# # Text - NLP
#
# dataset.describe()

# %%
dataset.drop('id', axis = 1, inplace = True)

# %%
dataset.describe()
# Out:
#               cont1         cont2         cont3         cont4         cont5  \
# count  99999.000000  99999.000000  99999.000000  99999.000000  99999.000000
# mean       0.493260      0.507171      0.498688      0.491163      0.487174
# std        0.187698      0.207297      0.202302      0.211479      0.208837
# min        0.000016      0.001149      0.002634      0.176921      0.281143
# 25%        0.346090      0.358319      0.336963      0.327354      0.281143
# 50%        0.475784      0.555782      0.527991      0.452887      0.422268
# 75%        0.623912      0.681761      0.634224      0.652072      0.635304
# max        0.984452      0.862654      0.944251      0.952482      0.983674
#
#               cont6         cont7         cont8         cont9        cont10  \
# count  99999.000000  99999.000000  99999.000000  99999.000000  99999.000000
# mean       0.490602      0.484355      0.485546      0.485119      0.497531
# std        0.205240      0.178139      0.198704      0.181772      0.185748
# min        0.012683      0.069503      0.236880      0.000080      0.000000
# 25%        0.335056      0.350175      0.312800      0.358970      0.364580
# 50%        0.440945      0.437799      0.441060      0.437310      0.461190
# 75%        0.654756      0.590568      0.617950      0.558550      0.614590
# max        0.997162      1.000000      0.980200      0.993790      0.994980
#
#              cont11        cont12        cont13        cont14           loss
# count  99999.000000  99999.000000  99999.000000  99999.000000   99999.000000
# mean       0.492874      0.492543      0.493291      0.496732    3040.359437
# std        0.209512      0.209156      0.212668      0.222587    2922.202773
# min        0.035321      0.036232      0.000228      0.180268       5.250000
# 25%        0.310961      0.308395      0.315758      0.294839    1200.785000
# 50%        0.457203      0.462286      0.363547      0.410939    2119.080000
# 75%        0.678924      0.675759      0.689974      0.724797    3869.965000
# max        0.998742      0.998484      0.988494      0.844848  121012.250000

# %%
dataset.shape
# Out:
# (99999, 131)

# %%
dataset.columns
# Out:
# Index(['cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8', 'cat9',
#        'cat10',
#        ...
#        'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12',
#        'cont13', 'cont14', 'loss'],
#       dtype='object', length=131)

# %%
sns.distplot(dataset['cont1'])
plt.show()

# %%
sns.distplot(dataset['cont7'])
plt.show()

# %% [raw]
# #distribution skew

# %%
dataset['cont1'].skew()
# Out:
# 0.52051950203360098

# %%
dataset.skew()
# Out:
# cont1     0.520520
# cont2    -0.314446
# cont3    -0.008636
# cont4     0.421105
# cont5     0.685966
# cont6     0.459900
# cont7     0.830577
# cont8     0.681937
# cont9     1.075352
# cont10    0.358455
# cont11    0.282744
# cont12    0.292981
# cont13    0.379578
# cont14    0.241355
# loss      4.186536
# dtype: float64

# %%
dataset['loss'].apply(np.log).skew()
# Out:
# 0.093386089657042495

# %%
dataset['loss'].skew()
# Out:
# 4.1865363491554035

# %%
dataset['loss'] = dataset['loss'].apply(np.log)

# %%
dataset['loss'].skew()
# Out:
# 0.093386089657042495

# %% [raw]
# # Kurtosis

# %%
dataset['cont7'].kurtosis()
# Out:
# 0.060773729559140399

# %%
# Leptokurtic
# Thick-tailed
dataset.kurtosis()
# Out:
# cont1    -0.091878
# cont2    -0.893709
# cont3    -0.611526
# cont4    -0.964874
# cont5    -0.868461
# cont6    -0.764037
# cont7     0.060774
# cont8    -0.527510
# cont9     0.572534
# cont10   -0.845007
# cont11   -1.047024
# cont12   -1.025892
# cont13   -1.351657
# cont14   -1.534417
# loss     -0.146967
# dtype: float64

# %%
split = 116
size = 15
data = dataset.iloc[:, split:]
data.shape
# Out:
# (99999, 15)

# %%
data.head()
# Out:
#       cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0  0.726300  0.245921  0.187583  0.789639  0.310061  0.718367  0.335060
# 1  0.330514  0.737068  0.592681  0.614134  0.885834  0.438917  0.436585
# 2  0.261841  0.358319  0.484196  0.236924  0.397069  0.289648  0.315545
# 3  0.321594  0.555782  0.527991  0.373816  0.422268  0.440945  0.391128
# 4  0.273204  0.159990  0.527991  0.473202  0.704268  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14      loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  7.702186
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  7.157424
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  8.008063
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642  6.845720
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  7.924380

# %%
import matplotlib.pyplot as plt

# %%
cols = data.columns
n_cols = 2
n_rows = 7

#violin plot, 7 * 2 grid
for i in range(n_rows):
    fg, ax = plt.subplots(nrows = 1, ncols = n_cols, figsize = (6, 6))
    for j in range(n_cols):
        sns.violinplot(y = cols[i * n_cols + j], data = dataset, ax = ax[j])
plt.show()

#cont2 spike at specific points

# %%
sns.distplot(dataset['cont5'])
plt.show()

# %%
sns.distplot(dataset['cont14'])
plt.show()

# %%
sns.violinplot(data = dataset, y = 'loss')
plt.show()

# %%
#Data Interaction - Correlation
# Correlation between feature and target (loss)
# Correlation between amonge features
# Correlation - Pearson
g = sns.heatmap(dataset.corr(), annot = True, fmt = '.2f', cmap = 'coolwarm')
plt.show()

# %%
data_corr = data.corr()
threshold = 0.5
corr_list = []
for i in range(0, size):
    for j in range(i + 1, size):
        if (data_corr.iloc[i, j] >= threshold and data_corr.iloc[i, j] < 1) or (data_corr.iloc[i, j] < 0 and data_corr.iloc[i, j] <= -threshold):
            corr_list.append([data_corr.iloc[i, j], i, j])
            
s_corr_list = sorted(corr_list, key = lambda x: -abs(x[0]))
for v, i, j in s_corr_list:
    print("%s and %s = %.2f" % (cols[i], cols[j], v))

#Strong Correlation
# Out:
# cont11 and cont12 = 0.99
# cont1 and cont9 = 0.93
# cont6 and cont10 = 0.88
# cont6 and cont13 = 0.82
# cont1 and cont10 = 0.81
# cont6 and cont9 = 0.80
# cont6 and cont12 = 0.79
# cont9 and cont10 = 0.79
# cont6 and cont11 = 0.77
# cont1 and cont6 = 0.76
# cont7 and cont11 = 0.75
# cont7 and cont12 = 0.74
# cont10 and cont12 = 0.71
# cont10 and cont13 = 0.71
# cont10 and cont11 = 0.70
# cont6 and cont7 = 0.66
# cont9 and cont13 = 0.64
# cont9 and cont12 = 0.63
# cont1 and cont12 = 0.61
# cont9 and cont11 = 0.61
# cont1 and cont11 = 0.60
# cont1 and cont13 = 0.53
# cont4 and cont8 = 0.53

# %%
# Scatter Plot

for v, i, j in s_corr_list:
    sns.pairplot(dataset, size = 4, x_vars = cols[i], y_vars = cols[j])
    plt.show()

# %%
cols = dataset.columns
# 29 * 4 grid
n_cols = 4
n_rows = 29

for i in range(n_rows):
    fg, ax = plt.subplots(nrows = 1, ncols = n_cols, sharey = True, figsize = (6,6))
    for j in range(n_cols):
        sns.countplot(x = cols[i * n_cols + j], data = dataset, ax = ax[j])

plt.show()
# Out:
# /home/stephen/miniconda3/envs/gluon/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
